# %% [markdown]
# ### An example of the SIGW inverse problem with the full numerical integration

# %%
import sys
sys.path.append('../')
from jax import vmap, jit, grad, random, jacfwd
from jax.lax import map
import jax.numpy as jnp
import numpy as np
import time
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm, colors
import warnings
from jax import config
config.update("jax_enable_x64", True)
import numpyro
from interpolation.omega_gw_jax import OmegaGWjax
from interpolation.model import Fixed_Nodes_Model, Free_Nodes_Model, spline_predict
from getdist import plots,MCSamples,loadMCSamples
# %config InlineBackend.figure_format = 'retina'
font = {'size'   : 16, 'family':'serif'}
axislabelfontsize='large'
matplotlib.rc('font', **font)
matplotlib.rc('text', usetex=True) # if using latex in plots
matplotlib.rc('legend', fontsize=16)

# %% [markdown]
# #### A simple test curvature power spectrum and $\Omega_{\rm GW}$

# %%
# set up the power spectrum and omgw
psize = 50
ksize = 60
k_arr = jnp.geomspace(5e-5,1e-2,ksize)
p_arr = jnp.geomspace(min(k_arr)/2,max(k_arr)*2,psize)

f = k_arr #jnp.geomspace(5e-5, 1e-2, ksize)  # The frequencies to calculate Omega_GW
s = jnp.linspace(0, 1, 10)  # First rescaled internal momentum
t = jnp.logspace(-3,3, 100)  # Second rescaled internal momentum

## Expand t to add a new axis
t_expanded = jnp.expand_dims(t, axis=-1)
## Repeat t along the new axis to match the shape (100, 1000)
t = jnp.repeat(t_expanded, len(f), axis=-1)

@jit
def pz(p,pstar=5e-4,n1=3,n2=-2,sigma=2):
    nir = n1
    pl1 = (p/pstar)**nir
    nuv = (n2 - n1)/sigma
    pl2 = (1+(p/pstar)**sigma)**nuv
    # osc = (1 + 16.4*jnp.cos(1.4*jnp.log(p/1.))**2)
    return pl1 * pl2 #*osc

gwb_calculator =  OmegaGWjax(s, t, f=f, kernel="RD", upsample=False)


pz_amp = pz(p_arr)
gwb_amp = gwb_calculator(pz,f)
kstar = 1e-3
omks_sigma = gwb_amp*( 0.1*(np.log(k_arr/kstar))**2 + 0.05) # 2% error at kstar + more towards edges
gwb_cov = jnp.diag(omks_sigma**2)

fig,(ax1,ax2) = plt.subplots(1,2,figsize=(10,3.5))
ax1.scatter(p_arr,pz_amp,s=2)
ax1.set_ylabel(r'$P_{\zeta}(k)$')
ax2.set_ylabel(r'$\Omega_{\mathrm{GW}}(k)$')
ax2.scatter(f,gwb_amp,s=2)
ax2.fill_between(k_arr,gwb_amp+1.96*omks_sigma,gwb_amp-1.96*omks_sigma,alpha=0.2,color='C0')
for ax in [ax1,ax2]:
    ax.set(yscale='log',xscale='log',xlabel=r'$k$')
fig.tight_layout();

# %%
# Set up the fixed node interpolator
kmin, kmax = min(p_arr), max(p_arr)
gwb_method_kwargs = {'s': s, 't': t}
pz_model = Fixed_Nodes_Model(n_nodes=4,pz_kmin=kmin,pz_kmax=kmax,
                            gwb_karr=k_arr,gwb_means=gwb_amp,
                            gwb_cov=gwb_cov,gwb_method='jax',gwb_method_kwargs=gwb_method_kwargs,y_low=-5,y_high=1)

# %%
# run the HMC
samples, extras = pz_model.run_hmc_inference(num_warmup=512,num_samples=512,seed=0)
# Out:
# sample: 100%|██████████| 1024/1024 [01:46<00:00,  9.64it/s, 7 steps of size 3.40e-01. acc. prob=0.91]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#       y[0]     -4.91      0.10     -4.94     -5.00     -4.78    120.85      1.02
#       y[1]     -1.07      0.02     -1.07     -1.09     -1.04    252.77      1.00
#       y[2]     -1.29      0.01     -1.29     -1.31     -1.28    308.59      1.00
#       y[3]     -4.04      0.18     -4.03     -4.32     -3.74    166.49      1.01
#
# Number of divergences: 0

# %% [markdown]
# #### Now we plot some realisations of the inferred $P_{\zeta}$ from the MCMC samples

# %%
nodes = pz_model.log_k_nodes
ys = samples['y'][::32] #jnp.median(samples['y'])
ff = lambda y: spline_predict(x_train=nodes,y_train=y,x_pred=f)

def omega_f(y):
    res = pz_model.get_gwb_from_xy(x=nodes,y=y)
    return res
gwb_amps = map(omega_f,ys)

ff = lambda y: spline_predict(x_train=nodes,y_train=y,x_pred=p_arr)
pz_amps = vmap(ff,)(ys)
print(pz_amps.shape)
# gwb_amps = jnp.einsum("pi,pj,kij->pk",pz_amps,pz_amps,gwb_calculator.omkij)
# print(gwb_amps.shape)

fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,4))

for i,pz in enumerate(pz_amps):
    ax1.loglog(p_arr,pz,alpha=0.5)
    ax1.scatter(10**(nodes),10**(ys[i]),s=16,alpha=0.5)
for om in gwb_amps:
    ax2.loglog(k_arr,om,alpha=0.5)
ax1.loglog(p_arr,pz_amp,color='k',lw=1.5)
ax2.plot(k_arr,gwb_amp,color='k',lw=1.5,label='Truth')
ax2.fill_between(k_arr,gwb_amp+1.96*omks_sigma,gwb_amp-1.96*omks_sigma,alpha=0.2,color='C0')
ax2.set(yscale='log',xscale='log')
                                                                                                                                                                                                       
ax1.set_ylabel(r'$P_{\zeta}(k)$')
ax1.set_xlabel(r'$k$')
# ax2.set_ylim(1e-11,1e-6)

ax2.set_ylabel(r'$\Omega_{\mathrm{GW}}(k)$')
ax2.set_xlabel(r'$k$')
ax2.legend()
for val in nodes:
    ax1.axvline(10**(val),color='k',ls='-.',alpha=0.5)
fig.tight_layout()
# the dashed lines represent the spline node locations
# Out:
# (16, 50)

# %%
### Plot the MC realisations with their logprob
cmap = matplotlib.colormaps['Reds']
ys = samples['y']
lp = -extras["potential_energy"] # PE = -negative logprob
lp_min, lp_max = np.min(lp), np.max(lp)
cols = (lp-lp_min)/(lp_max - lp_min) # normalise the logprob to a colour
norm = colors.Normalize(lp_min,lp_max)

fig, (ax1,ax2) = plt.subplots(1,2,figsize=(12,4),layout='constrained')
pz_amps = vmap(ff,)(ys)
for i,pz in enumerate(pz_amps):
    ax1.loglog(p_arr,pz,alpha=0.25,color=cmap(cols[i]))
    # ax1.scatter(10**(nodes),10**(ys[i]),s=16,alpha=0.5)
for om in gwb_amps:
    ax2.loglog(k_arr,om,alpha=0.25,color=cmap(cols[i]))
ax1.loglog(p_arr,pz_amp,color='k',lw=1.5)
ax2.loglog(k_arr,gwb_amp,color='k',lw=1.5,label='Truth')

ax2.legend()
ax1.set_ylabel(r'$P_{\zeta}(k)$')
ax1.set_xlabel(r'$k$')
# ax2.set_ylim(1e-11,1e-6)

ax2.set_ylabel(r'$\Omega_{\mathrm{GW}}(k)$')
ax2.set_xlabel(r'$k$')
fig.colorbar(cm.ScalarMappable(norm=norm,cmap=cmap),ax=[ax1,ax2],label='Logprob')
# fig.subplots_adjust(hspace=0.3)
# fig.tight_layout()

# %% [markdown]
# #### Do an optimization instead of HMC sampling

# %%
from interpolation.model import optim_scipy_bh , optim_optax
nodes = pz_model.log_k_nodes
best_idx = jnp.argmin(extras['potential_energy'])
worst_idx = jnp.argmax(extras['potential_energy'])
print(samples['y'][worst_idx])
x0 = samples['y'][best_idx]  
print(x0)
# x0 = -1.5*jnp.ones(5)
# best_params, _ = optim_scipy_bh(x0 = x0,loss = pz_model.loss,bounds=len(x0)*[(-7,1)],stepsize=0.2,niter=20) 
best_params, _ =  optim_optax(x0 = x0, loss = pz_model.loss, start_learning_rate=0.3 , steps = 100, jump_sdev=1.,y_low=-7.,y_high=1.)
print(best_params)
pz_bf = lambda x: spline_predict(x_train=nodes,y_train=best_params,x_pred=x)
# gwb_calculator =  OmegaGWjax(s, t, f=f, kernel="RD", upsample=False)
gwb_bf = pz_model.get_gwb_from_xy(x=nodes,y=best_params) #gwb_calculator(pz_bf,f) #jnp.einsum("i,j,kij->k",pz_bf,pz_bf,gwb_calculator.omkij)
# Out:
# [-4.99998118 -1.06652882 -1.2873902  -3.74507878]
# [-4.92103268 -1.0652835  -1.29375411 -3.96584929]
# [-7.         -1.15852105 -1.31034412 -3.13551528]

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,4))

ax1.loglog(p_arr,pz_bf(p_arr),color='r')
ax1.loglog(p_arr,pz_amp,color='k',lw=1.5)
ax2.plot(k_arr,gwb_amp,color='k',lw=1.5,label='Truth')
ax2.loglog(k_arr,gwb_bf,color='r',label='reconstructed')
ax2.fill_between(k_arr,gwb_amp+1.96*omks_sigma,gwb_amp-1.96*omks_sigma,alpha=0.2,color='C0')
ax2.set(yscale='log',xscale='log')

ax1.set_ylabel(r'$P_{\zeta}(k)$')
ax1.set_xlabel(r'$k$')
ax1.set_ylim(1e-5,1.)
# ax2.set_ylim(1e-11,1e-6)

ax2.set_ylabel(r'$\Omega_{\mathrm{GW}}(k)$')
ax2.set_xlabel(r'$k$')
ax2.legend()
for val in nodes:
    ax1.axvline(10**(val),color='k',ls='-.',alpha=0.5)
ax1.scatter(10**(nodes),10**(best_params),color='r')
fig.tight_layout()

# %% [markdown]
# #### Testing with the free nodes model

# %%
# Set up the free node interpolator
kmin, kmax = min(p_arr), max(p_arr)
gwb_method_kwargs = {'s': s, 't': t}
pz_model = Free_Nodes_Model(n_nodes=4,pz_kmin=kmin,pz_kmax=kmax,
                            gwb_karr=k_arr,gwb_means=gwb_amp,
                            gwb_cov=gwb_cov,gwb_method='jax',gwb_method_kwargs=gwb_method_kwargs,y_low=-5,y_high=1)

# %%
# run the HMC
samples, extras = pz_model.run_hmc_inference(num_warmup=512,num_samples=512,seed=0)
# Out:
# /Users/amk/Library/CloudStorage/OneDrive-SwanseaUniversity/Codes/SIGW_Inverse/examples/../interpolation/omega_gw_jax.py:184: SyntaxWarning: invalid escape sequence '\e'
#   """
# /Users/amk/Library/CloudStorage/OneDrive-SwanseaUniversity/Codes/SIGW_Inverse/examples/../interpolation/omega_gw_jax.py:263: SyntaxWarning: invalid escape sequence '\e'
#   """
# /Users/amk/Library/CloudStorage/OneDrive-SwanseaUniversity/Codes/SIGW_Inverse/examples/../interpolation/omega_gw_jax.py:813: SyntaxWarning: invalid escape sequence '\o'
#   """
# /Users/amk/Library/CloudStorage/OneDrive-SwanseaUniversity/Codes/SIGW_Inverse/examples/../interpolation/omega_gw_jax.py:838: SyntaxWarning: invalid escape sequence '\o'
#   """
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # run the HMC
# ----> 2 samples, extras = pz_model.run_hmc_inference(num_warmup=512,num_samples=512,seed=0)
#
# File ~/Library/CloudStorage/OneDrive-SwanseaUniversity/Codes/SIGW_Inverse/examples/../interpolation/model.py:251, in Interpolation_Model.run_hmc_inference(self, num_warmup, num_samples, num_chains, progress_bar, thinning, jit_model_args, dense_mass, max_tree_depth, seed, verbose)
#     243 mcmc = MCMC(kernel,num_warmup=num_warmup,
#     244         num_samples=num_samples,
#     245         num_chains=num_chains,
#     246         progress_bar=progress_bar,
#     247         thinning=thinning,
#     248         jit_model_args=jit_model_args)
#     250 rng_key, _ = random.split(random.PRNGKey(seed), 2)
# --> 251 mcmc.run(rng_key,self.extra_args,extra_fields=("potential_energy",)) # this can be made faster - parallel
#     252 samples = mcmc.get_samples()
#     253 extras = mcmc.get_extra_fields()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/numpyro/infer/mcmc.py:682, in MCMC.run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     680 map_args = (rng_key, init_state, init_params)
#     681 if self.num_chains == 1:
# --> 682     states_flat, last_state = partial_map_fn(map_args)
#     683     states = jax.tree.map(lambda x: x[jnp.newaxis, ...], states_flat)
#     684 else:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/numpyro/infer/mcmc.py:443, in MCMC._single_chain_mcmc(self, init, args, kwargs, collect_fields, remove_sites)
#     441 # Check if _sample_fn is None, then we need to initialize the sampler.
#     442 if init_state is None or (getattr(self.sampler, "_sample_fn", None) is None):
# --> 443     new_init_state = self.sampler.init(
#     444         rng_key,
#     445         self.num_warmup,
#     446         init_params,
#     447         model_args=args,
#     448         model_kwargs=kwargs,
#     449     )
#     450     init_state = new_init_state if init_state is None else init_state
#     451 sample_fn, postprocess_fn = self._get_cached_fns()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/numpyro/infer/hmc.py:749, in HMC.init(self, rng_key, num_warmup, init_params, model_args, model_kwargs)
#     744 # vectorized
#     745 else:
#     746     rng_key, rng_key_init_model = jnp.swapaxes(
#     747         vmap(random.split)(rng_key), 0, 1
#     748     )
# --> 749 init_params = self._init_state(
#     750     rng_key_init_model, model_args, model_kwargs, init_params
#     751 )
#     752 if self._potential_fn and init_params is None:
#     753     raise ValueError(
#     754         "Valid value of `init_params` must be provided with" " `potential_fn`."
#     755     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/numpyro/infer/hmc.py:693, in HMC._init_state(self, rng_key, model_args, model_kwargs, init_params)
#     686 def _init_state(self, rng_key, model_args, model_kwargs, init_params):
#     687     if self._model is not None:
#     688         (
#     689             new_init_params,
#     690             potential_fn,
#     691             postprocess_fn,
#     692             model_trace,
# --> 693         ) = initialize_model(
#     694             rng_key,
#     695             self._model,
#     696             dynamic_args=True,
#     697             init_strategy=self._init_strategy,
#     698             model_args=model_args,
#     699             model_kwargs=model_kwargs,
#     700             forward_mode_differentiation=self._forward_mode_differentiation,
#     701         )
#     702         if init_params is None:
#     703             init_params = new_init_params
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/numpyro/infer/util.py:662, in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     652 model_kwargs = {} if model_kwargs is None else model_kwargs
#     653 substituted_model = substitute(
#     654     seed(model, rng_key if is_prng_key(rng_key) else rng_key[0]),
#     655     substitute_fn=init_strategy,
#     656 )
#     657 (
#     658     inv_transforms,
#     659     replay_model,
#     660     has_enumerate_support,
#     661     model_trace,
# --> 662 ) = _get_model_transforms(substituted_model, model_args, model_kwargs)
#     663 # substitute param sites from model_trace to model so
#     664 # we don't need to generate again parameters of `numpyro.module`
#     665 model = substitute(
#     666     model,
#     667     data={
#    (...)
#     671     },
#     672 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/numpyro/infer/util.py:456, in _get_model_transforms(model, model_args, model_kwargs)
#     454 def _get_model_transforms(model, model_args=(), model_kwargs=None):
#     455     model_kwargs = {} if model_kwargs is None else model_kwargs
# --> 456     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#     457     inv_transforms = {}
#     458     # model code may need to be replayed in the presence of deterministic sites
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/numpyro/handlers.py:171, in trace.get_trace(self, *args, **kwargs)
#     163 def get_trace(self, *args, **kwargs):
#     164     """
#     165     Run the wrapped callable and return the recorded trace.
#     166
#    (...)
#     169     :return: `OrderedDict` containing the execution trace.
#     170     """
# --> 171     self(*args, **kwargs)
#     172     return self.trace
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/numpyro/primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# File ~/Library/CloudStorage/OneDrive-SwanseaUniversity/Codes/SIGW_Inverse/examples/../interpolation/model.py:424, in Free_Nodes_Model.model(self, extra_args)
#     419 x_full = numpyro.deterministic("x",jnp.concatenate
#     420                                ([jnp.array([self.logk_min]),
#     421                                  jnp.array(x_transformed),
#     422                                  jnp.array([self.logk_max])]) )
#     423 train_y = self.sample_y()
# --> 424 gwb = super().get_gwb_from_xy(x_full,train_y)
#     425 # numpyro.sample('omk',dist.Normal(omks_mean,omks_sigma),obs=omks_gp) # this assumes omks are independent, if off-diagonal cov use below
#     426 numpyro.sample('omk',dist.MultivariateNormal(loc=self.gwb_means,covariance_matrix=self.gwb_cov),obs=gwb)
#
# File ~/Library/CloudStorage/OneDrive-SwanseaUniversity/Codes/SIGW_Inverse/examples/../interpolation/model.py:342, in Fixed_Nodes_Model.get_gwb_from_xy(self, x, y, extra_args)
#     340 else:
#     341     pz_interp = lambda k: self.spline(k=k,x=x,y=y)
# --> 342     gwb = self.gwb_func(pz_interp,self.gwb_karr)
#     343 return gwb
#
# File ~/Library/CloudStorage/OneDrive-SwanseaUniversity/Codes/SIGW_Inverse/examples/../interpolation/omega_gw_jax.py:806, in OmegaGWjax.__call__(self, P_zeta, fvec, *params)
#     803 else:
#     804     t = self.t(kvec, *params)
# --> 806 res = self.integration_routine(P_zeta, s, t, kvec, *params)
#     808 out = 2 * self.norm(kvec_full_resolution) * res # * self.upsample_k(kvec_full_resolution, kvec, res)
#     810 return out
#
# File ~/Library/CloudStorage/OneDrive-SwanseaUniversity/Codes/SIGW_Inverse/examples/../interpolation/omega_gw_jax.py:831, in OmegaGWjax.integrate_constant_kernel(self, P_zeta, s, t, kvec, *params)
#     812 def integrate_constant_kernel(self, P_zeta, s, t, kvec, *params):
#     813     """
#     814     Compute the integral for the non-transitioning kernels.
#     815
#    (...)
#     829         Array of :math:`\overline{\mathcal{P}_h}` values.
#     830     """
# --> 831     integrand_values = self.integrand(P_zeta, self.kernel, s[:, None, None], t[None, :, :],
#     832                                         kvec[None, None, :], *params)
#     834     s_integrated = simpson_uniform(integrand_values, s)
#     835     return simpson_nonuniform(s_integrated, t)
#
#     [... skipping hidden 11 frame]
#
# File ~/Library/CloudStorage/OneDrive-SwanseaUniversity/Codes/SIGW_Inverse/examples/../interpolation/omega_gw_jax.py:429, in integrand(P_zeta, kernel, s, t, k, *params)
#     410 def integrand(P_zeta, kernel, s, t, k, *params):
#     411     """
#     412     Integrand for the non-transitioning kernels.
#     413
#    (...)
#     426         Tuple of parameters for the P_zeta function.
#     427     """
#     428     return kernel(t, s, k) * polynomial(t, s) * \
# --> 429         P_zeta(k*u(t, s), *params) * \
#     430         P_zeta(k*v(t, s), *params)
#
# File ~/Library/CloudStorage/OneDrive-SwanseaUniversity/Codes/SIGW_Inverse/examples/../interpolation/model.py:341, in Fixed_Nodes_Model.get_gwb_from_xy.<locals>.<lambda>(k)
#     339     gwb = self.gwb_func(pz_interp,self.gwb_karr,*extra_args)
#     340 else:
# --> 341     pz_interp = lambda k: self.spline(k=k,x=x,y=y)
#     342     gwb = self.gwb_func(pz_interp,self.gwb_karr)
#     343 return gwb
#
# File ~/Library/CloudStorage/OneDrive-SwanseaUniversity/Codes/SIGW_Inverse/examples/../interpolation/model.py:331, in Fixed_Nodes_Model.spline(self, x, y, k)
#     330 def spline(self,x, y, k):
# --> 331     pz = spline_predict(x_train=x,y_train=y,x_pred=k) #
#     332     pz = jnp.where(log10(k)<self.logk_min,0.,pz)
#     333     pz = jnp.where(log10(k)>self.logk_max,0.,pz)
#
#     [... skipping hidden 11 frame]
#
# File ~/Library/CloudStorage/OneDrive-SwanseaUniversity/Codes/SIGW_Inverse/examples/../interpolation/model.py:64, in spline_predict(x_train, y_train, x_pred)
#      60 """
#      61 Obtain spline prediction after exponentiating log10 P_zeta spline.
#      62 """
#      63 x_pred = log10(x_pred)
# ---> 64 return pow10(spline_predict_log(x_train,y_train,x_pred))
#
#     [... skipping hidden 11 frame]
#
# File ~/Library/CloudStorage/OneDrive-SwanseaUniversity/Codes/SIGW_Inverse/examples/../interpolation/model.py:54, in spline_predict_log(x_train, y_train, x_pred)
#      49 @jit
#      50 def spline_predict_log(x_train,y_train,x_pred):
#      51     """
#      52     Cubic spline to interpolate log10 P_zeta as a function of log10_k
#      53     """
# ---> 54     spl = CubicSpline(x_train,y_train,check=False)
#      55     y_pred = spl(x_pred)
#      56     return y_pred
#
#     [... skipping hidden 3 frame]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/interpax/_ppoly.py:804, in CubicSpline.__init__(self, x, y, axis, bc_type, extrapolate, check)
#     794 def __init__(
#     795     self,
#     796     x: jax.Array,
#    (...)
#     801     check: bool = True,
#     802 ):
#     803     x, _, y, axis, _ = prepare_input(x, y, axis, check=check)
# --> 804     df = approx_df(x, y, "cubic2", axis, bc_type=bc_type)
#     805     super().__init__(x, y, df, axis=axis, extrapolate=extrapolate, check=check)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/interpax/_fd_derivs.py:47, in approx_df(x, f, method, axis, **kwargs)
#      44 def fun(x, f):
#      45     return _approx_df(x, f, method, axis, **kwargs)
# ---> 47 return jit(fun)(x, f)
#
#     [... skipping hidden 11 frame]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/interpax/_fd_derivs.py:45, in approx_df.<locals>.fun(x, f)
#      44 def fun(x, f):
# ---> 45     return _approx_df(x, f, method, axis, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/interpax/_fd_derivs.py:54, in _approx_df(x, f, method, axis, c, bc_type)
#      52     out = _cubic1(x, f, axis)
#      53 elif method == "cubic2":
# ---> 54     out = _cubic2(x, f, axis, bc_type=bc_type)
#      55 elif method == "cardinal":
#      56     out = _cardinal(x, f, axis, c=c)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/interpax/_fd_derivs.py:159, in _cubic2(x, f, axis, bc_type)
#     157 dxr = dx.reshape([dx.shape[0]] + [1] * (f.ndim - 1))
#     158 dxi = jnp.where(dxr == 0, 0, 1 / jnp.where(dxr == 0, 1, dxr))
# --> 159 df = dxi * df
#     160 n = len(f)
#     162 # If bc is 'not-a-knot' this change is just a convention.
#     163 # If bc is 'periodic' then we already checked that y[0] == y[-1],
#     164 # and the spline is just a constant, we handle this case in the
#     165 # same way by setting the first derivatives to slope, which is 0.
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:1050, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1049 def op(self, *args):
# -> 1050   return getattr(self.aval, f"_{name}")(self, *args)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:573, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     571 args = (other, self) if swap else (self, other)
#     572 if isinstance(other, _accepted_binop_types):
# --> 573   return binary_op(*args)
#     574 # Note: don't use isinstance here, because we don't want to raise for
#     575 # subclasses, e.g. NamedTuple objects that may override operators.
#     576 if type(other) in _rejected_binop_types:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/jax/_src/numpy/ufunc_api.py:177, in ufunc.__call__(self, out, where, *args)
#     175   raise NotImplementedError(f"where argument of {self}")
#     176 call = self.__static_props['call'] or self._call_vectorized
# --> 177 return call(*args)
#
#     [... skipping hidden 11 frame]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/jax/_src/numpy/ufuncs.py:1187, in _multiply(x, y)
#    1161 """Multiply two arrays element-wise.
#    1162
#    1163 JAX implementation of :obj:`numpy.multiply`. This is a universal function,
#    (...)
#    1184   Array([ 0, 10, 20, 30], dtype=int32)
#    1185 """
#    1186 x, y = promote_args("multiply", x, y)
# -> 1187 return lax.mul(x, y) if x.dtype != bool else lax.bitwise_and(x, y)
#
#     [... skipping hidden 7 frame]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cosmo/lib/python3.12/site-packages/jax/_src/lax/lax.py:2072, in broadcasting_shape_rule(name, *avals)
#    2070       result_shape.append(non_1s[0])
#    2071     else:
# -> 2072       raise TypeError(f'{name} got incompatible shapes for broadcasting: '
#    2073                       f'{", ".join(map(str, map(tuple, shapes)))}.')
#    2075 return tuple(result_shape)
#
# TypeError: mul got incompatible shapes for broadcasting: (5,), (3,).
